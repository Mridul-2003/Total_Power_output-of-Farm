# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Tasmania_Data.csv")
data.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  546.1931  194.5337  160.0840  435.5412  220.8238  449.5166  396.1027
# 1  281.0669  390.3761  561.0742  295.9217  565.5344  236.3035  393.0648
# 2  566.0000  566.0000  346.5334  202.2120  389.6777  277.7876  421.9610
# 3    2.1045  352.3969  285.2965  566.0000  532.4306  176.8103  566.0000
# 4  168.5854  550.6155    0.0000  566.0000  450.8427    0.0000  566.0000
#
#          X8        X9       X10  ...           P8           P9          P10  \
# 0  231.7794   69.3599  474.1572  ...  216324.3888  242794.9467  234589.0464
# 1  340.0667  213.7463  457.8913  ...  228315.9892  196579.4315  265924.2946
# 2  260.3339  464.1620  566.0000  ...  216919.6851  210539.3646  234470.2783
# 3    0.0000  234.7225  485.8672  ...  231355.4783  267915.4110  239599.8014
# 4  566.0000  458.9008  227.8836  ...  212278.2632  199341.9985  230549.7763
#
#            P11          P12          P13          P14          P15  \
# ...

# %%
data.shape
# Out:
# (4678, 49)

# %%
data.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  4678.000000  4678.000000  4678.000000  4678.000000  4678.000000
# mean    293.085391   239.041576   227.899377   255.520394   247.646886
# std     173.814717   191.182858   183.535779   185.435953   194.237037
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     148.042400    48.801050    54.186725    96.100525    54.969650
# 50%     321.610800   225.285650   206.745150   229.476850   230.821300
# 75%     419.475850   399.058250   368.373175   416.365225   415.495400
# max     566.000000   566.000000   566.000000   566.000000   566.000000
#
#                 X6           X7           X8           X9          X10  ...  \
# count  4678.000000  4678.000000  4678.000000  4678.000000  4678.000000  ...
# mean    299.445828   235.883868   266.018186   304.659273   285.285471  ...
# std     182.532731   181.802905   171.084853   169.569231   192.989754  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4678 entries, 0 to 4677
# Data columns (total 49 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   X1        4678 non-null   float64
#  1   X2        4678 non-null   float64
#  2   X3        4678 non-null   float64
#  3   X4        4678 non-null   float64
#  4   X5        4678 non-null   float64
#  5   X6        4678 non-null   float64
#  6   X7        4678 non-null   float64
#  7   X8        4678 non-null   float64
#  8   X9        4678 non-null   float64
#  9   X10       4678 non-null   float64
#  10  X11       4678 non-null   float64
#  11  X12       4678 non-null   float64
#  12  X13       4678 non-null   float64
#  13  X14       4678 non-null   float64
#  14  X15       4678 non-null   float64
#  15  X16       4678 non-null   float64
#  16  Y1        4678 non-null   float64
#  17  Y2        4678 non-null   float64
#  18  Y3        4678 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# X1          0
# X2          0
# X3          0
# X4          0
# X5          0
# X6          0
# X7          0
# X8          0
# X9          0
# X10         0
# X11         0
# X12         0
# X13         0
# X14         0
# X15         0
# X16         0
# Y1          0
# Y2          0
# Y3          0
# Y4          0
# Y5          0
# Y6          0
# Y7          0
# Y8          0
# Y9          1
# Y10         1
# Y11         1
# Y12         1
# Y13         1
# Y14         1
# Y15         1
# Y16         1
# P1          1
# P2          1
# P3          1
# P4          1
# P5          1
# P6          1
# P7          1
# P8          1
# P9          1
# P10         1
# P11         1
# P12         1
# P13         1
# P14         1
# P15         1
# P16         1
# PowerAll    1
# dtype: int64

# %%
data.dropna()
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 0     546.1931  194.5337  160.0840  435.5412  220.8238  449.5166  396.1027
# 1     281.0669  390.3761  561.0742  295.9217  565.5344  236.3035  393.0648
# 2     566.0000  566.0000  346.5334  202.2120  389.6777  277.7876  421.9610
# 3       2.1045  352.3969  285.2965  566.0000  532.4306  176.8103  566.0000
# 4     168.5854  550.6155    0.0000  566.0000  450.8427    0.0000  566.0000
# ...        ...       ...       ...       ...       ...       ...       ...
# 4672  470.1535   78.2870   51.3194  310.2768    0.0000  205.0958  242.2490
# 4673  566.0000  261.8154  202.9069   18.5210  127.0790  154.7175  195.5566
# 4674  479.9728   51.9982    0.0000    0.0000  122.5784  402.6435   19.7678
# 4675  199.0309   37.4189  461.1556    0.0000  193.7716  566.0000  219.3373
# 4676  414.3911  388.6407  307.3420   85.3927  184.9669  144.6494  165.2147
#
#             X8        X9       X10  ...           P8           P9  \
# ...

# %%
data.isnull().sum()
# Out:
# X1          0
# X2          0
# X3          0
# X4          0
# X5          0
# X6          0
# X7          0
# X8          0
# X9          0
# X10         0
# X11         0
# X12         0
# X13         0
# X14         0
# X15         0
# X16         0
# Y1          0
# Y2          0
# Y3          0
# Y4          0
# Y5          0
# Y6          0
# Y7          0
# Y8          0
# Y9          1
# Y10         1
# Y11         1
# Y12         1
# Y13         1
# Y14         1
# Y15         1
# Y16         1
# P1          1
# P2          1
# P3          1
# P4          1
# P5          1
# P6          1
# P7          1
# P8          1
# P9          1
# P10         1
# P11         1
# P12         1
# P13         1
# P14         1
# P15         1
# P16         1
# PowerAll    1
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# X1          0
# X2          0
# X3          0
# X4          0
# X5          0
# X6          0
# X7          0
# X8          0
# X9          0
# X10         0
# X11         0
# X12         0
# X13         0
# X14         0
# X15         0
# X16         0
# Y1          0
# Y2          0
# Y3          0
# Y4          0
# Y5          0
# Y6          0
# Y7          0
# Y8          0
# Y9          0
# Y10         0
# Y11         0
# Y12         0
# Y13         0
# Y14         0
# Y15         0
# Y16         0
# P1          0
# P2          0
# P3          0
# P4          0
# P5          0
# P6          0
# P7          0
# P8          0
# P9          0
# P10         0
# P11         0
# P12         0
# P13         0
# P14         0
# P15         0
# P16         0
# PowerAll    0
# dtype: int64

# %%
data.shape
# Out:
# (4677, 49)

# %%
data.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  4677.000000  4677.000000  4677.000000  4677.000000  4677.000000
# mean    293.100093   239.083029   227.897810   255.550532   247.675099
# std     173.830393   191.182274   183.555372   185.444322   194.248218
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     148.038100    48.849800    54.136300    96.074300    54.960200
# 50%     321.701900   225.746600   206.743800   229.606600   230.998400
# 75%     419.485100   399.154200   368.466400   416.418900   415.528100
# max     566.000000   566.000000   566.000000   566.000000   566.000000
#
#                 X6           X7           X8           X9          X10  ...  \
# count  4677.000000  4677.000000  4677.000000  4677.000000  4677.000000  ...
# mean    299.399411   235.900114   266.009188   304.648549   285.319973  ...
# std     182.524634   181.818948   171.102039   169.585775   192.995959  ...
# ...

# %%
print(data.corrwith(data['PowerAll']).sort_values(ascending=False))
# Out:
# PowerAll    1.000000
# P10         0.337293
# P4          0.335711
# P2          0.333257
# P13         0.321173
# P9          0.315849
# P11         0.299940
# X16         0.279600
# P12         0.278874
# Y4          0.268111
# Y2          0.254818
# P16         0.253263
# X10         0.240901
# X12         0.234103
# X15         0.222295
# P1          0.174789
# P15         0.154736
# P7          0.154173
# Y13         0.147763
# X6          0.134255
# X1          0.124036
# Y10         0.122444
# Y9          0.119043
# P5          0.112809
# Y7          0.093224
# Y11         0.077904
# Y5          0.075976
# X11         0.062853
# P6          0.031955
# X9          0.008397
# P14         0.003481
# X8         -0.020060
# P8         -0.030070
# P3         -0.056585
# X13        -0.059507
# Y1         -0.064192
# X14        -0.106893
# Y12        -0.109530
# Y14        -0.153774
# Y3         -0.160206
# X4         -0.174527
# X7         -0.189783
# Y8         -0.225257
# ...

# %%
X = data.drop(['PowerAll'],axis=1).values
Y = data["PowerAll"].values

# %%
Y
# Out:
# array([3648666.894, 3810742.386, 3745925.666, ..., 3799317.354,
#        3648873.761, 3652044.253])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3273, 48)
# (1404, 48)
# (3273,)
# (1404,)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
model = LinearRegression()
model1=Ridge()
model2=Lasso()
model3=ElasticNet()
model.fit(x_train,y_train)
model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
model3.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model1.score(x_train,y_train)
# Out:
# 1.0

# %%
model1.score(x_test,y_test)
# Out:
# 1.0

# %%
model2.score(x_train,y_train)
# Out:
# 0.9999999999999121

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model3.score(x_train,y_train)
# Out:
# 0.9999999999997615

# %%
model3.score(x_test,y_test)
# Out:
# 0.9999999999997594

# %%
y_predict_train=model.predict(x_train)
y_predict_test=model.predict(x_test)

# %%
import seaborn as sns
ax1 = sns.distplot(y_train, hist=False, color="r", label="Actual Value")
sns.distplot(y_predict_train, hist=False, color="b", label="Fitted Values" , ax=ax1)
# Out:
# <ipython-input-34-aafe60b68c94>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_train, hist=False, color="r", label="Actual Value")
# <ipython-input-34-aafe60b68c94>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train,y_predict_train)
plt.plot(y_train,y_predict_train,c='r')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
